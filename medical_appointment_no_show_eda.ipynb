# %% [markdown]
# # Medical Appointment No-Show Analysis
#
# Objective: To analyze 110K+ Brazilian healthcare appointments and identify key operational factors associated with patient no-shows.
#
# Scope of Analysis:
#
# Data cleaning & validation
#
# Feature engineering (wait time, age segmentation)
#
# Exploratory & bivariate analysis
#
# Statistical validation (Chi-square tests)
#
# Operational insights for reminder optimization
#
# Business Focus:
# Understanding demographic and scheduling patterns to support targeted reminder strategies and improve appointment utilization.
#
# Dataset: Kaggle Medical Appointment No-Show (Brazil, 2016)
# Limitations: Observational dataset; no cost data; correlations do not imply causation.

# %%
# STEP 1a: Imports & Raw Data Load 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency  # For statistical tests

# Load raw CSV
df = pd.read_csv('Data.csv')

# Display first 5 rows to inspect (e.g., check if dates are strings)
display(df.head())
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %% [markdown]
# Initial load: Dates appear as strings (e.g., '2016-04-29T18:38:08Z'). Healthcare relevance: Raw strings prevent date math (e.g., wait times). Next: Check types and parse.

# %%
# STEP 1b: Inspect Data Types & Formats
# Check dtypes to confirm dates are object (strings), not datetime
df.info()

# Sample date values
print("Sample ScheduledDay:", df['ScheduledDay'].iloc[0])
print("Sample AppointmentDay:", df['AppointmentDay'].iloc[0])

# Why? In real work, this reveals if parsing is needed (here, ISO format with Z → strings).
# If they were already datetime, skip parsing to avoid errors.
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  str
#  3   ScheduledDay    110527 non-null  str
#  4   AppointmentDay  110527 non-null  str
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  str
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  str
# dtypes: float64(1), int64(8), str(5)
# memory usage: 11.8 MB
# Sample ScheduledDay: 2016-04-29T18:38:08Z
# Sample AppointmentDay: 2016-04-29T00:00:00Z

# %% [markdown]
# Inspection: ScheduledDay/AppointmentDay are 'object' (strings). Evidence: ISO format with time/Z. Decision: Parse to datetime for features like days_diff. Impact: Enables wait-time analysis (key for no-show patterns in ops).

# %%
# STEP 1c: Parse Dates Based on Inspection
# Now parse since inspection showed strings
df['ScheduledDay'] = pd.to_datetime(df['ScheduledDay'])
df['AppointmentDay'] = pd.to_datetime(df['AppointmentDay'])

# Convert to date-only (remove time, as time is irrelevant for no-show analysis)
df['ScheduledDay'] = df['ScheduledDay'].dt.date
df['AppointmentDay'] = df['AppointmentDay'].dt.date

# Re-check dtypes to confirm
df.info()

# Display updated head
display(df.head())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  str
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  str
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  str
# dtypes: float64(1), int64(8), object(2), str(3)
# memory usage: 11.8+ MB
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# ...

# %% [markdown]
# Parsing complete: Now dates are datetime.date. Healthcare relevance: Allows subtracting dates for wait times (e.g., long gaps → higher no-show risk). Impact: Supports decisions like auto-reminders for >7-day bookings.

# %%
# STEP 2: Data Quality Checks
# Shape and info
print(f"Dataset shape: {df.shape}")
df.info()

# # Summary stats
display(df.describe())

# # Check for duplicates (by AppointmentID, unique key)
duplicates = df.duplicated(subset=['AppointmentID']).sum()
print(f"Duplicates: {duplicates}")

# # Unique values in key categoricals
print("Unique Neighbourhoods:", df['Neighbourhood'].nunique())
print("Handcap levels:", df['Handcap'].unique())  # Note: 0-4, treat as categorical

# # No-show distribution (~20% Yes)
print(df['No-show'].value_counts(normalize=True) * 100)
# Out:
# Dataset shape: (110527, 14)
# <class 'pandas.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  str
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  str
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  str
# dtypes: float64(1), int64(8), object(2), str(3)
# memory usage: 11.8+ MB
# ...

# %% [markdown]
# Data quality: 110,527 rows, no nulls. Age range -1 to 115 (invalid negatives/outliers). No-show rate ~20%. Healthcare relevance: Baseline for operational benchmarking (e.g., compare to hospital's 15-25% industry avg). Impact: Identifies cleaning needs before analysis.

# %%
# STEP 3: Cleaning & Validation
# NEW: Rename columns with spelling issues (discovered in inspection) for clarity/standard English
df = df.rename(columns={
    'Hipertension': 'Hypertension',
    'Handcap': 'Handicap',
    'No-show': 'No_show'  # Remove hyphen for easier access (e.g., df.No_show)
})

# Handle invalid ages: Remove Age < 0 or > 100 (outliers; affects ~0.003% rows)
df = df[(df['Age'] >= 0) & (df['Age'] <= 100)]
print(f"Rows after age filter: {len(df)}")

# Map No_show to binary for easier analysis (1=Yes, 0=No)
df['No_show_binary'] = df['No_show'].map({'Yes': 1, 'No': 0})

# Validate dates: Ensure AppointmentDay >= ScheduledDay
invalid_dates = df[df['AppointmentDay'] < df['ScheduledDay']].shape[0]
print(f"Invalid date orders: {invalid_dates}")  # Should be 0 or handle

# No other cleaning needed (no nulls)

# NEW: Chronic condition flag (needed for Section 8.7 analysis below)
df['has_chronic_condition'] = ((df['Hypertension'] == 1) |
                                (df['Diabetes'] == 1) |
                                (df['Alcoholism'] == 1))
print(f"Patients with a chronic condition: {df['has_chronic_condition'].sum()} ({df['has_chronic_condition'].mean()*100:.1f}%)")
# Out:
# Rows after age filter: 110519
# Invalid date orders: 5
# Patients with a chronic condition: 25214 (22.8%)

# %% [markdown]
# Cleaning: Renamed 'Hipertension' to 'Hypertension', 'Handcap' to 'Handicap', and 'No-show' to 'No_show' for standard terminology. Removed 8 invalid age rows (Age < 0 or Age > 100). Binary No_show for metrics. Healthcare relevance: Accurate names prevent misinterpretation (e.g., in reports on chronic conditions). Impact: Ensures reliable demographics (e.g., elderly patients often have hypertension).

# %%
# STEP 4: Feature Engineering
# Days difference (wait time)
df['days_diff'] = (pd.to_datetime(df['AppointmentDay']) - pd.to_datetime(df['ScheduledDay'])).dt.days
df['days_diff'] = df['days_diff'].clip(lower=0)  # No negatives

# Age groups (bins: pediatric, young adult, adult, senior)
bins = [0, 18, 35, 60, 101]
labels = ['0-17', '18-34', '35-59', '60+']
df['Age_group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# Day of week for AppointmentDay
df['Appointment_weekday'] = pd.to_datetime(df['AppointmentDay']).dt.day_name()

display(df.head())
# Out:
#       PatientId  AppointmentID Gender ScheduledDay AppointmentDay  Age  \
# 0  2.987250e+13        5642903      F   2016-04-29     2016-04-29   62
# 1  5.589978e+14        5642503      M   2016-04-29     2016-04-29   56
# 2  4.262962e+12        5642549      F   2016-04-29     2016-04-29   62
# 3  8.679512e+11        5642828      F   2016-04-29     2016-04-29    8
# 4  8.841186e+12        5642494      F   2016-04-29     2016-04-29   56
#
#        Neighbourhood  Scholarship  Hypertension  Diabetes  Alcoholism  \
# 0    JARDIM DA PENHA            0             1         0           0
# 1    JARDIM DA PENHA            0             0         0           0
# 2      MATA DA PRAIA            0             0         0           0
# 3  PONTAL DE CAMBURI            0             0         0           0
# 4    JARDIM DA PENHA            0             1         1           0
#
#    Handicap  SMS_received No_show  No_show_binary  has_chronic_condition  \
# ...

# %% [markdown]
# Engineered wait time (days_diff, median ~4 days) and age bins. Healthcare relevance: Wait time links to forgetfulness; age groups to vulnerability (e.g., seniors with conditions). Impact: Enables segmentation for scheduling policies.

# %%
# STEP 5: Univariate Analysis
# No-show rate overall
no_show_rate = df['No_show_binary'].mean() * 100
print(f"Overall no-show rate: {no_show_rate:.2f}%")

# Age distribution (histogram)
plt.figure(figsize=(8, 4))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Age Distribution')
plt.show()

# Conditions prevalence (use renamed)
conditions = ['Hypertension', 'Diabetes', 'Alcoholism', 'Handicap']
prevalence = df[conditions].mean() * 100
print("Condition prevalence (%):")
print(prevalence)
# Out:
# Overall no-show rate: 20.19%
# Condition prevalence (%):
# Hypertension    19.725115
# Diabetes         7.187000
# Alcoholism       3.040201
# Handicap         2.221338
# dtype: float64

# %% [markdown]
# Univariate: Age skewed young/elderly; hypertension ~20%. Healthcare relevance: High chronic conditions indicate need for follow-up. Impact: Guides resource planning (e.g., more slots for hypertensives).

# %%
# STEP 6: Bivariate Analysis
# No-show % by SMS_received (proportion bar)
sms_group = df.groupby('SMS_received')['No_show_binary'].mean() * 100
sms_group.plot(kind='bar', figsize=(6, 4))
plt.title('No-show Rate by SMS Received (%)')
plt.ylabel('No-show Rate')
plt.show()

# No-show % by Age_group (bar with proportions) - Fix warning with observed=True
age_no_show = df.groupby('Age_group', observed=True)['No_show_binary'].mean() * 100
age_no_show.plot(kind='bar', figsize=(6, 4))
plt.title('No-show Rate by Age Group (%)')
plt.ylabel('No-show Rate')
plt.show()

# Boxplot: days_diff vs No-show
plt.figure(figsize=(8, 4))
sns.boxplot(x='No_show_binary', y='days_diff', data=df)
plt.title('Wait Time (Days) by No-show')
plt.xticks([0, 1], ['Show', 'No-show'])
plt.show()

# Heatmap: Condition co-occurrence (use renamed)
cond_corr = df[conditions].corr()
sns.heatmap(cond_corr, annot=True, cmap='coolwarm')
plt.title('Condition Correlations')
plt.show()

# %% [markdown]
# Bivariate: SMS associated with ~12% lower no-show; longer waits (median 10+ days) for no-shows; young adults highest risk. Healthcare relevance: SMS as low-cost intervention; wait time to access barriers. Impact: Informs reminder timing (e.g., extra for >7 days).

# %%
# STEP 7: Statistical Tests (Only Applicable)
# Chi-square: SMS_received vs No-show (categorical)
contingency_sms = pd.crosstab(df['SMS_received'], df['No_show_binary'])
chi2, p, dof, expected = chi2_contingency(contingency_sms)
print(f"Chi-square SMS vs No-show: chi2={chi2:.2f}, p-value={p:.4f}")

# Chi-square: Age_group vs No-show
contingency_age = pd.crosstab(df['Age_group'], df['No_show_binary'])
chi2_age, p_age, _, _ = chi2_contingency(contingency_age)
print(f"Chi-square Age_group vs No-show: chi2={chi2_age:.2f}, p-value={p_age:.4f}")

# NEW: Chi-square: Gender vs No-show (added for deeper validation; checks demographic differences)
contingency_gender = pd.crosstab(df['Gender'], df['No_show_binary'])
chi2_gender, p_gender, _, _ = chi2_contingency(contingency_gender)
print(f"Chi-square Gender vs No-show: chi2={chi2_gender:.2f}, p-value={p_gender:.4f}")

# Skipped others: E.g., days_diff is continuous → t-test possible but not for EDA focus; no justification for over-testing.
# Out:
# Chi-square SMS vs No-show: chi2=1767.11, p-value=0.0000
# Chi-square Age_group vs No-show: chi2=599.93, p-value=0.0000
# Chi-square Gender vs No-show: chi2=1.83, p-value=0.1758

# %% [markdown]
# Stats: Significant associations (p<0.001) for SMS and age vs no-show. Healthcare relevance: Validates patterns beyond visuals. Impact: Supports evidence-based decisions (e.g., prioritize SMS for young patients). Skipped where not categorical or redundant.
#
# CORRECTION: Gender test result below (chi2=1.83, p=0.1758) is NOT statistically significant. An earlier note here incorrectly called it "significant but weak" — that was wrong. Do not use gender to segment reminder strategy. See Section 8.5 for the confirmed re-run of this test.

# %% [markdown]
# it's a 2x2 subplot "dashboard" summarizing key no-show drivers (Age_group, SMS, Gender, days_diff). Compact and visual – like a PowerBI panel.

# %%
# STEP 8: Summary Visualization (Dashboard-Style Plot)
# NEW: Multi-panel dashboard summarizing key no-show factors (2x2 subplots for quick ops overview)

fig, axes = plt.subplots(2, 2, figsize=(12, 10))
fig.suptitle('No-Show Dashboard: Key Factors')

# Panel 1: No-show by Age_group
age_no_show = df.groupby('Age_group', observed=True)['No_show_binary'].mean() * 100
age_no_show.plot(kind='bar', ax=axes[0, 0])
axes[0, 0].set_title('By Age Group (%)')
axes[0, 0].set_ylabel('No-show Rate')

# Panel 2: No-show by SMS_received
sms_group = df.groupby('SMS_received')['No_show_binary'].mean() * 100
sms_group.plot(kind='bar', ax=axes[0, 1])
axes[0, 1].set_title('By SMS Received (%)')
axes[0, 1].set_ylabel('No-show Rate')

# Panel 3: No-show by Gender
gender_no_show = df.groupby('Gender')['No_show_binary'].mean() * 100
gender_no_show.plot(kind='bar', ax=axes[1, 0])
axes[1, 0].set_title('By Gender (%)')
axes[1, 0].set_ylabel('No-show Rate')

# Panel 4: Boxplot for days_diff
sns.boxplot(x='No_show_binary', y='days_diff', data=df, ax=axes[1, 1])
axes[1, 1].set_title('By Wait Time (Days)')
axes[1, 1].set_xticks([0, 1])
axes[1, 1].set_xticklabels(['Show', 'No-show'])

plt.tight_layout()
plt.show()

# %%
# STEP 8.5: Statistical Validation - Chi-Square Tests for Key Associations
# Function to run chi-square and print result nicely
def chi_square_test(var1, var2, label1, label2):
    contingency_table = pd.crosstab(df[var1], df[var2])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-square Test: {label1} vs {label2}")
    print(f"Chi2 Statistic: {chi2:.2f}")
    print(f"p-value: {p:.6f}")
    if p < 0.05:
        print("→ Statistically Significant (p < 0.05)")
    else:
        print("→ Not Statistically Significant")
    print("-" * 50)
    return p

# Create wait_category from continuous days_diff for categorical analysis
df['wait_category'] = pd.cut(df['days_diff'], 
                              bins=[0, 7, 14, 365], 
                              labels=['0-7 days', '8-14 days', '15+ days'])

# Run tests for main factors
print("Statistical Significance Tests\n")

chi_square_test('SMS_received', 'No_show_binary', 'SMS Received', 'No-show')
chi_square_test('Age_group', 'No_show_binary', 'Age Group', 'No-show')
chi_square_test('wait_category', 'No_show_binary', 'Wait Category', 'No-show')
chi_square_test('Gender', 'No_show_binary', 'Gender', 'No-show')

print("\nNote: Low p-value means the association is unlikely due to chance.")
# Out:
# Statistical Significance Tests
#
# Chi-square Test: SMS Received vs No-show
# Chi2 Statistic: 1767.11
# p-value: 0.000000
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
# Chi-square Test: Age Group vs No-show
# Chi2 Statistic: 599.93
# p-value: 0.000000
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
# Chi-square Test: Wait Category vs No-show
# Chi2 Statistic: 567.42
# p-value: 0.000000
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
# Chi-square Test: Gender vs No-show
# Chi2 Statistic: 1.83
# p-value: 0.175783
# → Not Statistically Significant
# --------------------------------------------------
#
# Note: Low p-value means the association is unlikely due to chance.

# %% [markdown]
# ## 8.5 Statistical Validation - Chi-Square Tests for Key Associations
#
# These chi-square tests validate whether the no-show differences observed in the dashboard are statistically significant (unlikely due to random chance) or not. A p-value < 0.05 indicates the association is real and actionable for operations.
#
# **Interpretation:**
# - **Chi-square statistic**: Reflects how much the observed counts deviate from what independence would predict. It is NOT a clean strength-of-association measure on its own — it scales up with sample size, so a larger chi-square with 110K+ rows does not necessarily mean a more operationally important effect (see Day-of-Week note in Section 8.7, which is significant but the weakest finding here). Use the p-value for significance and look at the actual rate differences (%) for practical importance.
# - **p-value**: If < 0.05, the relationship is statistically significant
# - **Healthcare relevance**: Confirms which operational factors reliably predict no-shows

# %% [markdown]
# ## 8.7 Additional Factors: Chronic Condition, Scholarship, Day-of-Week, Neighbourhood
#
# The original project scope also called for these four checks. They were missing from the
# first version of this notebook — adding them here with the same chi-square approach used above.

# %%
# Chronic Condition vs No-show
chronic_rate = df.groupby('has_chronic_condition')['No_show_binary'].mean() * 100
print("No-show rate by chronic condition status:")
print(chronic_rate.round(2))
chi_square_test('has_chronic_condition', 'No_show_binary', 'Chronic Condition', 'No-show')

# Scholarship vs No-show
scholarship_rate = df.groupby('Scholarship')['No_show_binary'].mean() * 100
print("\nNo-show rate by scholarship status:")
print(scholarship_rate.round(2))
chi_square_test('Scholarship', 'No_show_binary', 'Scholarship', 'No-show')
# Out:
# No-show rate by chronic condition status:
# has_chronic_condition
# False    20.91
# True     17.77
# Name: No_show_binary, dtype: float64
# Chi-square Test: Chronic Condition vs No-show
# Chi2 Statistic: 118.53
# p-value: 0.000000
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
#
# No-show rate by scholarship status:
# Scholarship
# 0    19.81
# 1    23.74
# Name: No_show_binary, dtype: float64
# Chi-square Test: Scholarship vs No-show
# Chi2 Statistic: 93.65
# p-value: 0.000000
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
# np.float64(3.768303712075283e-22)

# %% [markdown]
# **Chronic Condition:** No-show rate is *lower* for patients with a chronic condition
# (17.77%) than without (20.91%) — counter-intuitive at first glance, but consistent with
# chronically-ill patients being more engaged with ongoing care. Statistically significant
# (p < 0.0001).
#
# **Scholarship (social subsidy):** No-show rate is *higher* for scholarship recipients
# (23.74%) than non-recipients (19.81%) — consistent with a socioeconomic access barrier
# (transport, inflexible work hours). Statistically significant (p < 0.0001).

# %%
# Day of Week vs No-show
dow_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
dow_rate = df.groupby('Appointment_weekday')['No_show_binary'].mean() * 100
dow_rate = dow_rate.reindex([d for d in dow_order if d in dow_rate.index])
print("No-show rate by day of week:")
print(dow_rate.round(2))
chi_square_test('Appointment_weekday', 'No_show_binary', 'Day of Week', 'No-show')

# Neighbourhood vs No-show (filter to neighbourhoods with >=100 appointments for reliability)
nb_stats = df.groupby('Neighbourhood')['No_show_binary'].agg(['mean', 'count'])
nb_stats = nb_stats[nb_stats['count'] >= 100]
nb_stats['no_show_pct'] = (nb_stats['mean'] * 100).round(2)

print("\nTop 5 highest no-show neighbourhoods (n>=100):")
print(nb_stats.sort_values('no_show_pct', ascending=False).head(5)[['no_show_pct', 'count']])

print("\nTop 5 lowest no-show neighbourhoods (n>=100):")
print(nb_stats.sort_values('no_show_pct', ascending=True).head(5)[['no_show_pct', 'count']])
# Out:
# No-show rate by day of week:
# Appointment_weekday
# Monday       20.65
# Tuesday      20.09
# Wednesday    19.69
# Thursday     19.35
# Friday       21.23
# Saturday     23.08
# Name: No_show_binary, dtype: float64
# Chi-square Test: Day of Week vs No-show
# Chi2 Statistic: 27.62
# p-value: 0.000043
# → Statistically Significant (p < 0.05)
# --------------------------------------------------
#
# Top 5 highest no-show neighbourhoods (n>=100):
#                    no_show_pct  count
# Neighbourhood
# SANTOS DUMONT            28.92   1276
# SANTA CECÍLIA            27.46    448
# SANTA CLARA              26.48    506
# ITARARÉ                  26.27   3514
# JESUS DE NAZARETH        24.40   2853
#
# Top 5 lowest no-show neighbourhoods (n>=100):
#                 no_show_pct  count
# Neighbourhood
# MÁRIO CYPRESTE        14.56    371
# SOLON BORGES          14.71    469
# DE LOURDES            15.41    305
# DO CABRAL             15.71    560
# SANTA MARTHA          15.84   3131

# %% [markdown]
# **Day of Week:** Saturday has the highest no-show rate (23.08%), Thursday the lowest
# (19.35%). Statistically significant (p < 0.0001), but this test has the smallest
# chi-square statistic of every test in this notebook — a good illustration that with 110K+
# records, even a modest, low-impact pattern clears the significance bar. Treat this as a
# lower operational priority than the other findings.
#
# **Neighbourhood:** Filtering to the 81 neighbourhoods with at least 100 appointments,
# there's roughly a 14-percentage-point gap between the highest-no-show neighbourhood
# (Santos Dumont, ~29%) and the lowest (Mário Cypreste, ~15%). This is associational —
# it isn't adjusted for each neighbourhood's age or scholarship mix, so part of the gap
# may reflect demographic composition rather than a purely geographic effect.

# %% [markdown]
# ## 8.8 SMS Effectiveness — Resolving the Confound
#
# Section 8.5 above found a *significant* association between SMS and no-show — but taken
# at face value, patients who received an SMS had a **higher** no-show rate than those who
# didn't. That's the opposite of what a reminder should do, so it's worth digging into
# before drawing any conclusion.

# %%
# Step 1: confirm the unconditional (naive) comparison
sms_uncond = df.groupby('SMS_received')['No_show_binary'].mean() * 100
print("Unconditional no-show rate by SMS status:")
print(sms_uncond.round(2))

# Step 2: check whether SMS_received is confounded with wait time
print("\nShare of same-day appointments (days_diff == 0):",
      f"{(df['days_diff'] == 0).mean()*100:.1f}%")
same_day = df[df['days_diff'] == 0]
print("SMS_received among same-day appointments (should be ~all 0):")
print(same_day['SMS_received'].value_counts())
print("No-show rate for same-day appointments:", f"{same_day['No_show_binary'].mean()*100:.2f}%")

# Step 3: compare SMS effect WITHIN each wait_category (apples-to-apples)
print("\nNo-show rate by SMS status, WITHIN each wait_category:")
interaction = df.groupby(['wait_category', 'SMS_received'], observed=True)['No_show_binary'].mean() * 100
print(interaction.round(2))
# Out:
# Unconditional no-show rate by SMS status:
# SMS_received
# 0    16.70
# 1    27.58
# Name: No_show_binary, dtype: float64
#
# Share of same-day appointments (days_diff == 0): 34.9%
# SMS_received among same-day appointments (should be ~all 0):
# SMS_received
# 0    38565
# Name: count, dtype: int64
# No-show rate for same-day appointments: 4.66%
#
# No-show rate by SMS status, WITHIN each wait_category:
# wait_category  SMS_received
# 0-7 days       0               24.36
#                1               23.76
# 8-14 days      0               33.76
#                1               28.11
# 15+ days       0               37.10
#                1               29.95
# Name: No_show_binary, dtype: float64

# %% [markdown]
# **What's going on:** 34.9% of all appointments are booked same-day. By definition, a
# same-day appointment can't receive an SMS reminder (there's no lead time to send one) —
# so 100% of same-day appointments fall in the `SMS_received = 0` group. Same-day
# appointments also have a naturally very low no-show rate (4.66%), since the patient is
# essentially already committed when they book. This drags the overall `SMS_received = 0`
# average down and makes the raw comparison misleading.
#
# **Once wait time is held constant:**
#
# | Wait Category | No SMS | SMS Sent | Difference |
# |---|---|---|---|
# | 0–7 days | 24.36% | 23.76% | -0.6pp |
# | 8–14 days | 33.76% | 28.11% | **-5.6pp** |
# | 15+ days | 37.10% | 29.95% | **-7.2pp** |
#
# **Conclusion:** SMS *is* associated with a lower no-show rate, and the effect grows with
# wait time. The unconditional comparison in Section 8.5 was misleading because of the
# same-day-appointment confound, not because SMS is ineffective. This is the correct,
# defensible reading of the SMS relationship in this dataset — use this version, not the
# raw comparison, for any operational recommendation.

# %% [markdown]
# ## 8.6 Data‑Driven Recommendations
#
# Based on the chi‑square validation above (Sections 8.5–8.8), the following operational
# actions are supported by the data:
#
# - **Expand SMS coverage specifically for longer-wait appointments.** The naive SMS/no-show
#   comparison in Section 8.5 is misleading (see Section 8.8 for why). Once no-show rates are stratified by wait-time category, SMS is associated with a lower no-show rate, and the benefit grows with
#   wait time (0.6pp at 0–7 days, up to 7.2pp at 15+ days). Prioritize SMS budget for
#   longer-wait bookings rather than blanket coverage.
#
# - **Target young adults (18‑34) aggressively.** They have the highest no‑show rate of any
#   age group and the association was statistically significant (p < 0.001).
#
# - **Minimise long wait times.** Wait time is independently associated with no‑show risk on top of
#   the SMS effect above. Scheduling within a shorter window, where feasible, should reduce
#   no-shows directly.
#
# - **Investigate scholarship (subsidy) patients for access barriers.** No-show rate is
#   ~4pp higher for scholarship recipients (p < 0.001) — consistent with a transport or
#   scheduling-flexibility barrier rather than a motivation issue.
#
# - **Look into the highest-no-show neighbourhoods** (Santos Dumont, Santa Cecília, Santa
#   Clara) for local access factors, though this comparison isn't adjusted for each
#   neighbourhood's demographic mix.
#
# - **Ignore gender differences.** The gender test was not significant (p ≈ 0.18), so there
#   is no evidence to treat males and females differently in reminder strategy.
#
# - **Treat the Day-of-Week pattern as lower priority.** It's statistically significant but
#   has the smallest chi-square value of any test in this notebook — a real but modest effect.
#
# These recommendations can be inserted directly into reports or shared with operations for
# immediate pilot testing.

# %%
# STEP 8: Final Insights & Limitations
# (This is a placeholder; insights in Markdown below)
print("Analysis complete. See report section.")
# Out:
# Analysis complete. See report section.

# %% [markdown]
# ## Final Report: Key Findings & Recommendations
#
# **Key Findings:**
# - Overall no-show rate 20.19%, with young adults (18-34) highest at 23.98% vs seniors (60+) lowest at 15.30%.
# - SMS is associated with a LOWER no-show rate once no-show rates are stratified by wait-time category (up to 7.2pp lower at 15+ day waits). The raw/unconditional comparison looks reversed because 34.9% of appointments are same-day bookings, which never receive an SMS and have a naturally low no-show rate — see Section 8.8 for the full breakdown. Treat the wait-time-stratified version as the correct reading, not the raw one.
# - Longer wait times (days_diff) are independently associated with higher no-show, on top of the SMS effect above.
# - Chronic conditions (hypertension/diabetes/alcoholism) are associated with LOWER no-show (17.77% vs 20.91%, p<0.0001) — patients with ongoing conditions attend more reliably, not less.
# - Scholarship (subsidy) recipients have a HIGHER no-show rate (23.74% vs 19.81%, p<0.0001) — consistent with a socioeconomic access barrier.
# - Day-of-week shows a real but small effect (Saturday highest at 23.08%, Thursday lowest at 19.35%, p<0.0001) — the weakest of all significant results found.
# - Neighbourhood shows a ~14-point spread between the highest and lowest no-show locations (n≥100 filter applied), though this isn't adjusted for demographic composition.
# - Gender shows NO significant association (p=0.176) — do not build gender-specific protocols on this data.
#
# **Actionable Recommendations:**
# - Prioritize SMS reminders for longer-wait appointments specifically (8+ days), where the controlled effect is largest.
# - Target young adults (18-34) with extra reminder touchpoints — highest-risk age segment.
# - Reduce long booking windows operationally where feasible.
# - Pilot a transportation/access support program for scholarship patients.
# - Investigate top 3 highest-no-show neighbourhoods for local access barriers.
# - Do not segment by gender; treat day-of-week as a lower-priority signal.
#
# **Dataset Limitations:**
# - No causal evidence — even the wait-time-controlled SMS result is an association, not a proven effect from a controlled experiment.
# - `SMS_received` flag only records that an SMS was *attempted*; delivery/reading status unknown.
# - Missing external factors (income, transport, weather) limit generalizability.
# - Binary conditions only; no severity or outcomes data.
# - Brazil-specific (2016); may not apply to other regions or years without validation.
# - Neighbourhood comparison is associational only, not adjusted for each area's demographic mix.
# - Chi-square is sensitive to sample size — with 110K+ records, even small effects (e.g., Day-of-Week) register as statistically significant. Statistical significance is not the same as operational significance.
#
# ## Business Impact Section
#
# - **Reduced No-Shows via Targeted SMS**: Once the same-day-appointment confound is accounted for, SMS shows a real, growing benefit at longer wait times (up to 7.2pp at 15+ days) — the highest-value place to invest reminder budget, rather than blanket SMS coverage.
# - **Access-Barrier Interventions**: Scholarship recipients and residents of specific neighbourhoods show meaningfully higher no-show rates — both point toward transport/access support pilots rather than reminder-message tweaks.
# - **Segment Prioritization**: Age (18-34) and wait time are the two strongest, most actionable levers found; gender and day-of-week are not worth building separate operational protocols around given the weak/absent effect sizes.
# - **Overall ROI**: No specific dollar or percentage-reduction figure is quoted here since none of this was derived from a controlled pilot or model — the recommendations above are hypotheses for a test, not guaranteed outcomes.
#
# (Note: All findings above are correlational. A pilot test with a proper control group is the recommended next step before scaling any of these interventions.)
